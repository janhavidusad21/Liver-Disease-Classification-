# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/content/project-data (1) (1).csv")

# %%
df
# Out:
#     category;age;sex;albumin;alkaline_phosphatase;alanine_aminotransferase;aspartate_aminotransferase;bilirubin;cholinesterase;cholesterol;creatinina;gamma_glutamyl_transferase ;protein
# 0     no_disease;32;m;38.5;52.5;7.7;22.1;7.5;6.93;3...
# 1     no_disease;32;m;38.5;70.3;18;24.7;3.9;11.17;4...
# 2     no_disease;32;m;46.9;74.7;36.2;52.6;6.1;8.84;...
# 3     no_disease;32;m;43.2;52;30.6;22.6;18.9;7.33;4...
# 4     no_disease;32;m;39.2;74.1;32.6;24.8;9.6;9.15;...
# ..                                                 ...
# 610   cirrhosis;62;f;32;416.6;5.9;110.3;50;5.57;6.3...
# 611   cirrhosis;64;f;24;102.8;2.9;44.4;20;1.54;3.02...
# 612   cirrhosis;64;f;29;87.3;3.5;99;48;1.66;3.63;66...
# 613    cirrhosis;46;f;33;NA;39;62;20;3.56;4.2;52;50;71
# 614   cirrhosis;59;f;36;NA;100;80;12;9.07;5.3;67;34;68
#
# [615 rows x 1 columns]

# %%
df=pd.read_csv("/content/project-data (1) (1).csv",delimiter=";")

# %%
df
# Out:
#         category  age sex  albumin  alkaline_phosphatase  \
# 0     no_disease   32   m     38.5                  52.5
# 1     no_disease   32   m     38.5                  70.3
# 2     no_disease   32   m     46.9                  74.7
# 3     no_disease   32   m     43.2                  52.0
# 4     no_disease   32   m     39.2                  74.1
# ..           ...  ...  ..      ...                   ...
# 610    cirrhosis   62   f     32.0                 416.6
# 611    cirrhosis   64   f     24.0                 102.8
# 612    cirrhosis   64   f     29.0                  87.3
# 613    cirrhosis   46   f     33.0                   NaN
# 614    cirrhosis   59   f     36.0                   NaN
#
#      alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                         7.7                        22.1        7.5
# 1                        18.0                        24.7        3.9
# 2                        36.2                        52.6        6.1
# ...

# %%
df.shape
# Out:
# (615, 13)

# %% [markdown]
# **The dataset contains 615 records and 13 columns**

# %%
df.columns
# Out:
# Index(['category', 'age', 'sex', 'albumin', 'alkaline_phosphatase',
#        'alanine_aminotransferase', 'aspartate_aminotransferase', 'bilirubin',
#        'cholinesterase', 'cholesterol', 'creatinina',
#        'gamma_glutamyl_transferase ', 'protein   '],
#       dtype='object')

# %%
df= df.rename(columns={
    "protein   ": "protein",})

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There is No duplicate record in the dataset

# %%
df.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  614.000000            597.000000                614.000000
# mean    47.408130   41.620195             68.283920                 28.450814
# std     10.055105    5.780629             26.028315                 25.469689
# min     19.000000   14.900000             11.300000                  0.900000
# 25%     39.000000   38.800000             52.500000                 16.400000
# 50%     47.000000   41.950000             66.200000                 23.000000
# 75%     54.000000   45.200000             80.100000                 33.075000
# max     77.000000   82.200000            416.600000                325.300000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   605.000000
# mean                    34.786341   11.396748        8.196634     5.368099
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     615 non-null    object
#  1   age                          615 non-null    int64
#  2   sex                          615 non-null    object
#  3   albumin                      614 non-null    float64
#  4   alkaline_phosphatase         597 non-null    float64
#  5   alanine_aminotransferase     614 non-null    float64
#  6   aspartate_aminotransferase   615 non-null    float64
#  7   bilirubin                    615 non-null    float64
#  8   cholinesterase               615 non-null    float64
#  9   cholesterol                  605 non-null    float64
#  10  creatinina                   615 non-null    float64
#  11  gamma_glutamyl_transferase   615 non-null    float64
# ...

# %%
df['protein'] = pd.to_numeric(df['protein'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   category                     615 non-null    object
#  1   age                          615 non-null    int64
#  2   sex                          615 non-null    object
#  3   albumin                      614 non-null    float64
#  4   alkaline_phosphatase         597 non-null    float64
#  5   alanine_aminotransferase     614 non-null    float64
#  6   aspartate_aminotransferase   615 non-null    float64
#  7   bilirubin                    615 non-null    float64
#  8   cholinesterase               615 non-null    float64
#  9   cholesterol                  605 non-null    float64
#  10  creatinina                   615 non-null    float64
#  11  gamma_glutamyl_transferase   615 non-null    float64
# ...

# %%
df.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  615.000000            615.000000                615.000000
# mean    47.408130   41.620195             68.283920                 28.450814
# std     10.055105    5.775920             25.643955                 25.448940
# min     19.000000   14.900000             11.300000                  0.900000
# 25%     39.000000   38.800000             52.950000                 16.400000
# 50%     47.000000   41.900000             66.700000                 23.000000
# 75%     54.000000   45.200000             79.300000                 33.050000
# max     77.000000   82.200000            416.600000                325.300000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   615.000000
# mean                    34.786341   11.396748        8.196634     5.368099
# ...

# %%
df.isnull().sum()
# Out:
# category                        0
# age                             0
# sex                             0
# albumin                         1
# alkaline_phosphatase           18
# alanine_aminotransferase        1
# aspartate_aminotransferase      0
# bilirubin                       0
# cholinesterase                  0
# cholesterol                    10
# creatinina                      0
# gamma_glutamyl_transferase      0
# protein                         1
# dtype: int64

# %% [markdown]
# The dataset contains missing value

# %% [markdown]
# # ***HANDLING NULL VALUES***

# %%
df["albumin"]=df["albumin"].fillna(df["albumin"].mean())
df["alkaline_phosphatase"]=df["alkaline_phosphatase"].fillna(df["alkaline_phosphatase"].mean())
df["alanine_aminotransferase"]=df["alanine_aminotransferase"].fillna(df["alanine_aminotransferase"].mean())
df["cholesterol"]=df["cholesterol"].fillna(df["cholesterol"].mean())
df["protein"]=df["protein"].fillna(df["protein"].mean())

# %%
df.isnull().sum()
# Out:
# category                       0
# age                            0
# sex                            0
# albumin                        0
# alkaline_phosphatase           0
# alanine_aminotransferase       0
# aspartate_aminotransferase     0
# bilirubin                      0
# cholinesterase                 0
# cholesterol                    0
# creatinina                     0
# gamma_glutamyl_transferase     0
# protein                        0
# dtype: int64

# %%
df
# Out:
#         category  age sex  albumin  alkaline_phosphatase  \
# 0     no_disease   32   m     38.5              52.50000
# 1     no_disease   32   m     38.5              70.30000
# 2     no_disease   32   m     46.9              74.70000
# 3     no_disease   32   m     43.2              52.00000
# 4     no_disease   32   m     39.2              74.10000
# ..           ...  ...  ..      ...                   ...
# 610    cirrhosis   62   f     32.0             416.60000
# 611    cirrhosis   64   f     24.0             102.80000
# 612    cirrhosis   64   f     29.0              87.30000
# 613    cirrhosis   46   f     33.0              68.28392
# 614    cirrhosis   59   f     36.0              68.28392
#
#      alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                         7.7                        22.1        7.5
# 1                        18.0                        24.7        3.9
# 2                        36.2                        52.6        6.1
# ...

# %%
df["category"].value_counts()
# Out:
# category
#  no_disease        533
#  cirrhosis          30
#  hepatitis          24
#  fibrosis           21
# suspect_disease      7
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# m    377
# f    238
# Name: count, dtype: int64

# %%
df["protein"]
# Out:
# 0      69.0
# 1      76.5
# 2      79.3
# 3      75.7
# 4      68.7
#        ...
# 610    68.5
# 611    71.3
# 612    82.0
# 613    71.0
# 614    68.0
# Name: protein, Length: 615, dtype: float64

# %%
df['category'].value_counts().plot(kind='bar', title="Category Distribution")
plt.show()

# %%
plt.hist(df['age'], bins=20, edgecolor='white',color="red")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
df['sex'].value_counts().plot(kind='bar', title="Sex Distribution")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="category", y="bilirubin", data=df)
plt.title("Bilirubin by Category")
plt.show()

# %%
sns.boxplot(x="category",y="alkaline_phosphatase",data=df)
plt.title("alkaline phosphatase by category")
plt.show()

# %%
sns.boxplot(x="category",y="alanine_aminotransferase",data=df)
plt.title("alanine aminotransferase by category")
plt.show()

# %%
sns.boxplot(x="category",y="aspartate_aminotransferase",data=df)
plt.title("aspartate aminotransferase by category")
plt.show()

# %%
sns.boxplot(x="category",y="creatinina",data=df)
plt.title("creatinina by category")
plt.show()

# %%
def cap_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # Winsorization (capping)
    data[column] = np.where(data[column] > upper, upper,
                            np.where(data[column] < lower, lower, data[column]))
    return data

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
print("Numeric columns:", numeric_cols)
# Out:
# Numeric columns: Index(['age', 'albumin', 'alkaline_phosphatase', 'alanine_aminotransferase',
#        'aspartate_aminotransferase', 'bilirubin', 'cholinesterase',
#        'cholesterol', 'creatinina', 'gamma_glutamyl_transferase ', 'protein'],
#       dtype='object')

# %%
df_capped = df.copy()
for col in numeric_cols:
    df_capped = cap_outliers_iqr(df_capped, col)

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.boxplot(x=df['bilirubin'])
plt.title("Before Outlier Handling")

plt.subplot(1,2,2)
sns.boxplot(x=df_capped['bilirubin'])
plt.title("After Outlier Capping")

plt.show()

# %% [markdown]
# **Handles outliers in each column using IQR-based capping**

# %%
df_capped.to_csv("outlier_cleaned.csv", index=False)

# %%
df_clean=pd.read_csv("outlier_cleaned.csv")

# %%
df_clean
# Out:
#         category   age sex  albumin  alkaline_phosphatase  \
# 0     no_disease  32.0   m     38.5              52.50000
# 1     no_disease  32.0   m     38.5              70.30000
# 2     no_disease  32.0   m     46.9              74.70000
# 3     no_disease  32.0   m     43.2              52.00000
# 4     no_disease  32.0   m     39.2              74.10000
# ..           ...   ...  ..      ...                   ...
# 610    cirrhosis  62.0   f     32.0             118.82500
# 611    cirrhosis  64.0   f     29.2             102.80000
# 612    cirrhosis  64.0   f     29.2              87.30000
# 613    cirrhosis  46.0   f     33.0              68.28392
# 614    cirrhosis  59.0   f     36.0              68.28392
#
#      alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                       7.700                       22.10       7.50
# 1                      18.000                       24.70       3.90
# ...

# %%
df_clean.describe()
# Out:
#               age     albumin  alkaline_phosphatase  alanine_aminotransferase  \
# count  615.000000  615.000000            615.000000                615.000000
# mean    47.407317   41.702472             67.344977                 25.869026
# std     10.052729    4.987356             19.779151                 13.500221
# min     19.000000   29.200000             13.425000                  0.900000
# 25%     39.000000   38.800000             52.950000                 16.400000
# 50%     47.000000   41.900000             66.700000                 23.000000
# 75%     54.000000   45.200000             79.300000                 33.050000
# max     76.500000   54.800000            118.825000                 58.025000
#
#        aspartate_aminotransferase   bilirubin  cholinesterase  cholesterol  \
# count                  615.000000  615.000000      615.000000   615.000000
# mean                    28.668130    8.879431        8.202309     5.359774
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df_clean['category'] = le.fit_transform(df_clean['category'])

print("Classes:", le.classes_)
# Out:
# Classes: [' cirrhosis' ' fibrosis' ' hepatitis' ' no_disease' 'suspect_disease']

# %%
df_clean['sex'] = df_clean['sex'].map({'m': 0, 'f': 1})

# %%
df_clean
# Out:
#      category   age  sex  albumin  alkaline_phosphatase  \
# 0           3  32.0    0     38.5              52.50000
# 1           3  32.0    0     38.5              70.30000
# 2           3  32.0    0     46.9              74.70000
# 3           3  32.0    0     43.2              52.00000
# 4           3  32.0    0     39.2              74.10000
# ..        ...   ...  ...      ...                   ...
# 610         0  62.0    1     32.0             118.82500
# 611         0  64.0    1     29.2             102.80000
# 612         0  64.0    1     29.2              87.30000
# 613         0  46.0    1     33.0              68.28392
# 614         0  59.0    1     36.0              68.28392
#
#      alanine_aminotransferase  aspartate_aminotransferase  bilirubin  \
# 0                       7.700                       22.10       7.50
# 1                      18.000                       24.70       3.90
# 2                      36.200                       49.85       6.10
# ...

# %%
print(df_clean.dtypes)
# Out:
# category                         int64
# age                            float64
# sex                              int64
# albumin                        float64
# alkaline_phosphatase           float64
# alanine_aminotransferase       float64
# aspartate_aminotransferase     float64
# bilirubin                      float64
# cholinesterase                 float64
# cholesterol                    float64
# creatinina                     float64
# gamma_glutamyl_transferase     float64
# protein                        float64
# dtype: object

# %%
scaler = StandardScaler()
scaled_data=scaler.fit_transform(df_clean)

# %%
x = df_clean.drop("category", axis=1)
y = df_clean["category"]

# %%
x
# Out:
#       age  sex  albumin  alkaline_phosphatase  alanine_aminotransferase  \
# 0    32.0    0     38.5              52.50000                     7.700
# 1    32.0    0     38.5              70.30000                    18.000
# 2    32.0    0     46.9              74.70000                    36.200
# 3    32.0    0     43.2              52.00000                    30.600
# 4    32.0    0     39.2              74.10000                    32.600
# ..    ...  ...      ...                   ...                       ...
# 610  62.0    1     32.0             118.82500                     5.900
# 611  64.0    1     29.2             102.80000                     2.900
# 612  64.0    1     29.2              87.30000                     3.500
# 613  46.0    1     33.0              68.28392                    39.000
# 614  59.0    1     36.0              68.28392                    58.025
#
#      aspartate_aminotransferase  bilirubin  cholinesterase  cholesterol  \
# ...

# %%
y
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 610    0
# 611    0
# 612    0
# 613    0
# 614    0
# Name: category, Length: 615, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
log_reg = LogisticRegression(multi_class="multinomial", max_iter=1000)
log_reg.fit(X_train, y_train)
y_pred_lr = log_reg.predict(X_test)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.926829268292683

# %% [markdown]
# The Accuracy Of Logistic Regression is 92%

# %% [markdown]
# **RandomForest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9349593495934959

# %%
print("\nClassification Report (Random Forest):\n",
      classification_report(y_test, y_pred_rf, target_names=le.classes_))
# Out:
# Classification Report (Random Forest):
#                   precision    recall  f1-score   support
#
#       cirrhosis       0.71      0.83      0.77         6
#        fibrosis       0.50      0.25      0.33         4
#       hepatitis       0.67      0.40      0.50         5
#      no_disease       0.96      1.00      0.98       107
# suspect_disease       0.00      0.00      0.00         1
#
#        accuracy                           0.93       123
#       macro avg       0.57      0.50      0.52       123
#    weighted avg       0.92      0.93      0.92       123

# %% [markdown]
# **The Accuracy Of RandomForest is 93%**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred_rf), annot=True, fmt="d", cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %% [markdown]
# **XGboost**

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(eval_metric='mlogloss', use_label_encoder=False, random_state=42)
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

print("\nXGBoost Accuracy:", accuracy_score(y_test, y_pred_xgb))
print(classification_report(y_test, y_pred_xgb, target_names=le.classes_))
# Out:
# XGBoost Accuracy: 0.926829268292683
#                  precision    recall  f1-score   support
#
#       cirrhosis       0.75      1.00      0.86         6
#        fibrosis       0.00      0.00      0.00         4
#       hepatitis       0.33      0.20      0.25         5
#      no_disease       0.96      1.00      0.98       107
# suspect_disease       0.00      0.00      0.00         1
#
#        accuracy                           0.93       123
#       macro avg       0.41      0.44      0.42       123
#    weighted avg       0.89      0.93      0.91       123

# %% [markdown]
# The Accuracy of XGboost is 92%

# %% [markdown]
# **LGBM**

# %%
from lightgbm import LGBMClassifier

lgb = LGBMClassifier(random_state=42)
lgb.fit(X_train, y_train)
y_pred_lgb = lgb.predict(X_test)

print("\nLightGBM Accuracy:", accuracy_score(y_test, y_pred_lgb))
print(classification_report(y_test, y_pred_lgb, target_names=le.classes_))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1352
# [LightGBM] [Info] Number of data points in the train set: 492, number of used features: 12
# [LightGBM] [Info] Start training from score -3.020425
# [LightGBM] [Info] Start training from score -3.365265
# [LightGBM] [Info] Start training from score -3.254040
# [LightGBM] [Info] Start training from score -0.144039
# [LightGBM] [Info] Start training from score -4.406719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# The Accuracy of the LGBM is 94%

# %% [markdown]
# **SVM**

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf', probability=True, random_state=42)
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

print("\nSVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm, target_names=le.classes_))
# Out:
# SVM Accuracy: 0.9105691056910569
#                  precision    recall  f1-score   support
#
#       cirrhosis       0.80      0.67      0.73         6
#        fibrosis       0.00      0.00      0.00         4
#       hepatitis       0.33      0.20      0.25         5
#      no_disease       0.93      1.00      0.96       107
# suspect_disease       0.00      0.00      0.00         1
#
#        accuracy                           0.91       123
#       macro avg       0.41      0.37      0.39       123
#    weighted avg       0.86      0.91      0.88       123

# %% [markdown]
# The accuracy of SVM is 91%

# %%
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred_xgb), annot=True, fmt="d",
            xticklabels=le.classes_, yticklabels=le.classes_, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - XGBoost")
plt.show()

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)


y_pred_dt = dt.predict(X_test)


print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt, target_names=le.classes_))

sns.heatmap(confusion_matrix(y_test, y_pred_dt), annot=True, fmt="d",
            xticklabels=le.classes_, yticklabels=le.classes_, cmap="Greens")
plt.title("Decision Tree - Confusion Matrix")
plt.show()
# Out:
# Decision Tree Accuracy: 0.9186991869918699
#                  precision    recall  f1-score   support
#
#       cirrhosis       0.60      1.00      0.75         6
#        fibrosis       0.40      0.50      0.44         4
#       hepatitis       0.50      0.20      0.29         5
#      no_disease       0.98      0.97      0.98       107
# suspect_disease       0.00      0.00      0.00         1
#
#        accuracy                           0.92       123
#       macro avg       0.50      0.53      0.49       123
#    weighted avg       0.92      0.92      0.91       123

# %% [markdown]
# The Accuracy of Decision Tree is 91%

# %% [markdown]
# **K-Nearest Neighbors (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)


print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn, target_names=le.classes_))

sns.heatmap(confusion_matrix(y_test, y_pred_knn), annot=True, fmt="d",
            xticklabels=le.classes_, yticklabels=le.classes_, cmap="Blues")
plt.title("KNN - Confusion Matrix")
plt.show()
# Out:
# KNN Accuracy: 0.9186991869918699
#                  precision    recall  f1-score   support
#
#       cirrhosis       0.83      0.83      0.83         6
#        fibrosis       0.00      0.00      0.00         4
#       hepatitis       0.33      0.20      0.25         5
#      no_disease       0.95      1.00      0.97       107
# suspect_disease       0.00      0.00      0.00         1
#
#        accuracy                           0.92       123
#       macro avg       0.42      0.41      0.41       123
#    weighted avg       0.88      0.92      0.90       123

# %% [markdown]
# The Accuracy of Knn is 91%

# %% [markdown]
# **Navie Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, y_train)

y_pred_nb = nb.predict(X_test)

print("Naive Bayes Accuracy:", accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb, target_names=le.classes_))

sns.heatmap(confusion_matrix(y_test, y_pred_nb), annot=True, fmt="d",
            xticklabels=le.classes_, yticklabels=le.classes_, cmap="Oranges")
plt.title("Naive Bayes - Confusion Matrix")
plt.show()
# Out:
# Naive Bayes Accuracy: 0.9105691056910569
#                  precision    recall  f1-score   support
#
#       cirrhosis       0.67      0.67      0.67         6
#        fibrosis       0.40      0.50      0.44         4
#       hepatitis       1.00      0.20      0.33         5
#      no_disease       0.95      0.98      0.97       107
# suspect_disease       0.00      0.00      0.00         1
#
#        accuracy                           0.91       123
#       macro avg       0.60      0.47      0.48       123
#    weighted avg       0.92      0.91      0.90       123

# %% [markdown]
# The Accuracy of Navie Bayes is 91%

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=FutureWarning)
from lightgbm import plot_importance
from sklearn.model_selection import cross_val_score
models = {
    "LightGBM": LGBMClassifier(random_state=42),
    "XGBoost": XGBClassifier(eval_metric="mlogloss", use_label_encoder=False, random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "KNN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM": SVC(kernel="rbf", probability=True, random_state=42)
}

# =====================
# 3. Train, Evaluate, Compare
# =====================
results = {}

for name, model in models.items():
    # Use scaled data where required
    if name in ["KNN", "Naive Bayes", "Logistic Regression", "SVM"]:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        cv_scores = cross_val_score(model, x, y, cv=5, scoring="accuracy")
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        cv_scores = cross_val_score(model, x, y, cv=5, scoring="accuracy")

    acc = accuracy_score(y_test, y_pred)
    results[name] = {
        "Accuracy": acc,
        "CV Mean": cv_scores.mean(),
        "Report": classification_report(y_test, y_pred, target_names=le.classes_, output_dict=True),
        "Predictions": y_pred
    }

    print(f"\n=== {name} ===")
    print("Test Accuracy:", acc)
    print("Cross-Validation Accuracy:", cv_scores.mean())
    print(classification_report(y_test, y_pred, target_names=le.classes_))

    # Confusion Matrix
    plt.figure(figsize=(6,4))
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues",
                xticklabels=le.classes_, yticklabels=le.classes_)
    plt.title(f"{name} - Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# =====================
# 4. Feature Importance (Tree-based Models only)
# =====================
best_model = models["LightGBM"]
best_model.fit(X_train, y_train)

plot_importance(best_model, max_num_features=15, importance_type="gain")
plt.title("LightGBM - Feature Importance")
plt.show()

# =====================
# 5. Summary Table
# =====================
summary = pd.DataFrame({name: {"Accuracy": r["Accuracy"], "CV Mean": r["CV Mean"]}
                        for name, r in results.items()}).T
print("\n=== Final Model Comparison Summary ===")
print(summary.sort_values("Accuracy", ascending=False))
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1352
# [LightGBM] [Info] Number of data points in the train set: 492, number of used features: 12
# [LightGBM] [Info] Start training from score -3.020425
# [LightGBM] [Info] Start training from score -3.365265
# [LightGBM] [Info] Start training from score -3.254040
# [LightGBM] [Info] Start training from score -0.144039
# [LightGBM] [Info] Start training from score -4.406719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# **THE LIGHTGBM GIIVES HIGH ACCURACY SO WE FINALIZED LIGHTGBM MODEL**
